# %% [markdown]
# # Setting Everything Up

# %%
import pandas as pd
from datetime import datetime

# %%
#import the file from the web
import requests
from bs4 import BeautifulSoup
import pandas as pd
from unicodedata import normalize
import re
from datetime import datetime
from pandas import read_csv 
from sklearn.feature_extraction.text import CountVectorizer
import json
from flatten_json import flatten


# I can give a number or use None to remove maximum ceiling & display all columns
pd.options.display.max_columns = None

# # I want to be able to see the entire narrative, so remove the maximum width for each column
# pd.options.display.max_colwidth = None

# pd.options.display.float_format = '{:,.0f}'.format

import string

# %matplotlib inline

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (8, 8)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %%R
#
# # My commonly used R imports
#
# require('tidyverse')
# Out:
# R[write to console]: Loading required package: tidyverse
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.0      ✔ purrr   1.0.1
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.3.0      ✔ stringr 1.5.0
# ✔ readr   2.1.3      ✔ forcats 1.0.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
#To Download PDFs
from urllib.parse import urljoin

# %%
#To import camelot and PDF-related items
import camelot
import ghostscript
import sys

# %%
# %%R
#
# library(jpeg)
# library(wordcloud)
# library(RColorBrewer)
# library(wordcloud2)
# library(tm)
# Out:
# R[write to console]: Loading required package: RColorBrewer
#
# R[write to console]: Loading required package: NLP
#
# R[write to console]:
# Attaching package: ‘NLP’
#
#
# R[write to console]: The following object is masked from ‘package:ggplot2’:
#
#     annotate

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
# %%R
# library(vistime)
# library(shiny)
# library(plotly)
# #for timeline plotting
# Out:
# R[write to console]:
# Attaching package: ‘plotly’
#
#
# R[write to console]: The following object is masked from ‘package:ggplot2’:
#
#     last_plot
#
#
# R[write to console]: The following object is masked from ‘package:stats’:
#
#     filter
#
#
# R[write to console]: The following object is masked from ‘package:graphics’:
#
#     layout

# %%
from collections import Counter

# %% [markdown]
# # Reading the Data

# %%
df_total_tiktoks=pd.read_csv("df_total_tiktoks.csv")
df_total_tiktoks
# Out:
#      number_orig    video_author  \
# 0              0   _sheee_gachie
# 1              1   francisgaitho
# 2              2        mbiiiish
# 3              3    lady_marichu
# 4              4  francisgaitho7
# ..           ...             ...
# 166           66     bydalesmith
# 167           67     chi_herself
# 168           68      pappi_doll
# 169           69     bubu_x_olly
# 170           70        _praizze
#
#                                       video_challenges video_comments  \
# 0    [LightChallenge(title='_sheee_gachie'), LightC...             []
# 1    [LightChallenge(title='whyyoulying'), LightCha...             []
# 2    [LightChallenge(title='mbiiiish'), LightChalle...             []
# 3    [LightChallenge(title='whyyoulyingchallenge'),...             []
# 4    [LightChallenge(title='844system'), LightChall...             []
# ..                                                 ...            ...
# ...

# %%
df_total_tiktoks['video_id_for_link']=df_total_tiktoks['video_tags'].str.extract("id=([\d]*) height=")
df_total_tiktoks
# Out:
#      number_orig    video_author  \
# 0              0   _sheee_gachie
# 1              1   francisgaitho
# 2              2        mbiiiish
# 3              3    lady_marichu
# 4              4  francisgaitho7
# ..           ...             ...
# 166           66     bydalesmith
# 167           67     chi_herself
# 168           68      pappi_doll
# 169           69     bubu_x_olly
# 170           70        _praizze
#
#                                       video_challenges video_comments  \
# 0    [LightChallenge(title='_sheee_gachie'), LightC...             []
# 1    [LightChallenge(title='whyyoulying'), LightCha...             []
# 2    [LightChallenge(title='mbiiiish'), LightChalle...             []
# 3    [LightChallenge(title='whyyoulyingchallenge'),...             []
# 4    [LightChallenge(title='844system'), LightChall...             []
# ..                                                 ...            ...
# ...

# %%
import asyncio

import numpy as np
import pandas as pd
from TikTokAPI import TikTokAPI



from tiktokapipy.async_api import AsyncTikTokAPI

async def get_video_link(x):
    # scroll down for 2.5 seconds when making requests
    async with AsyncTikTokAPI(scroll_down_time=2.5) as api:
        video_details = await api.video(video_id_for_link)
        async for video_deet in video_details.videos:
            video_url=video_deet.video_link
            print (video_url)
            
    
df_total_tiktoks ['link_found'] =  df_total_tiktoks.video_id_for_link.apply(get_video_link)
df_total_tiktoks ['link_found']





async def fun2(x):
    return x * 2


async def main():
    df = pd.DataFrame(np.arange(10), columns=['old'])
    df['new'] = await asyncio.gather(*(fun2(v) for v in df['old']))


asyncio.run(main())
# Out:
# 0      <coroutine object get_video_link at 0x2a72e4740>
# 1      <coroutine object get_video_link at 0x2a72e4640>
# 2      <coroutine object get_video_link at 0x2a72e4840>
# 3      <coroutine object get_video_link at 0x2a72e4940>
# 4      <coroutine object get_video_link at 0x2a72e4a40>
#                              ...
# 166    <coroutine object get_video_link at 0x2a732ee40>
# 167    <coroutine object get_video_link at 0x2a732ef40>
# 168    <coroutine object get_video_link at 0x2a732f040>
# 169    <coroutine object get_video_link at 0x2a732f140>
# 170    <coroutine object get_video_link at 0x2a732f240>
# Name: link_found, Length: 171, dtype: object

# %%
# import asyncio

import numpy as np
import pandas as pd
from TikTokAPI import TikTokAPI



from tiktokapipy.async_api import AsyncTikTokAPI




# def get_challenge_videos_scroll_down():
#     # scroll down for 2.5 seconds when making requests
#     with TikTokAPI(scroll_down_time=2.5) as api:
#         challenge = api.challenge(tag_name)
#         for video in challenge.videos:
#             ...
            
            
async def get_video_link(video_id_for_link):
    # scroll down for 2.5 seconds when making requests
    async with AsyncTikTokAPI(scroll_down_time=2.5) as api:
        video_details = api.video(video_id_for_link)
        video_url=video_link(video_details)

#         for video_deet in video_details:
#             video_url=video_deet.video_link
        print (video_url)
            
await get_video_link("7221139736071523590")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [44], line 32
#      28 #         for video_deet in video_details:
#      29 #             video_url=video_deet.video_link
#      30         print (video_url)
# ---> 32 await get_video_link("7221139736071523590")
#
# Cell In [44], line 26, in get_video_link(video_id_for_link)
#      24     async with AsyncTikTokAPI(scroll_down_time=2.5) as api:
#      25         video_details = api.video(video_id_for_link)
# ---> 26         video_url=video_link(video_details)
#      28 #         for video_deet in video_details:
#      29 #             video_url=video_deet.video_link
#      30         print (video_url)
#
# NameError: name 'video_link' is not defined

# %%
# import asyncio

import numpy as np
import pandas as pd
from TikTokAPI import TikTokAPI



from tiktokapipy.async_api import AsyncTikTokAPI




# def get_challenge_videos_scroll_down():
#     # scroll down for 2.5 seconds when making requests
#     with TikTokAPI(scroll_down_time=2.5) as api:
#         challenge = api.challenge(tag_name)
#         for video in challenge.videos:
#             ...
            
            
async def video_link(video_id_for_link):
    # scroll down for 2.5 seconds when making requests
    async with AsyncTikTokAPI(scroll_down_time=2.5) as api:
        video_details = api.video(video_id_for_link)
        video_url=video_link(video_details)

#         for video_deet in video_details:
#             video_url=video_deet.video_link
        print (video_url)
            
await get_video_link("7221139736071523590")

# %%
import numpy as np
import pandas as pd
# from TikTokAPI import TikTokAPI



from tiktokapipy.async_api import AsyncTikTokAPI

async def video_link(video_id_for_link):
    # scroll down for 2.5 seconds when making requests
    async with AsyncTikTokAPI(scroll_down_time=2.5) as api:
        video_details = api.video(video_id_for_link)
#         await video_link(video_details)
#         video_url=video_link(video_details)

#         for video_deet in video_details:
#             video_url=video_deet.video_link
        print (video_details)


await video_link("7221139736071523590")
# Out:
# <coroutine object AsyncTikTokAPI.video at 0x2acae7840>

# %%
from tiktokapipy.async_api import AsyncTikTokAPI

async def get_video_link(video_id_for_link):
    async with AsyncTikTokAPI() as api:
        video = await api.video(video_link)
        video_url=video.video_link
        print(video_url)

await get_video_link("7221139736071523590")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [61], line 9
#       6         video_url=video.video_link
#       7         print(video_url)
# ----> 9 await get_video_link("7221139736071523590")
#
# Cell In [61], line 5, in get_video_link(video_id_for_link)
#       3 async def get_video_link(video_id_for_link):
#       4     async with AsyncTikTokAPI() as api:
# ----> 5         video = await api.video(video_link)
#       6         video_url=video.video_link
#       7         print(video_url)
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/tiktokapipy/async_api.py:218, in AsyncTikTokAPI.video(self, link, scroll_down_time)
#     217 async def video(self, link: str, scroll_down_time: float = None) -> Video:
# --> 218     response, api_extras = await self._scrape_data(
#     219         link, self._video_response_type, scroll_down_time
#     220     )
# ...

# %%
from tiktokapipy.async_api import AsyncTikTokAPI

async with AsyncTikTokAPI() as api:
    video = await api.video("7221139736071523590")
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In [62], line 4
#       1 from tiktokapipy.async_api import AsyncTikTokAPI
#       3 async with AsyncTikTokAPI() as api:
# ----> 4     video = await api.video("7221139736071523590")
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/tiktokapipy/async_api.py:218, in AsyncTikTokAPI.video(self, link, scroll_down_time)
#     217 async def video(self, link: str, scroll_down_time: float = None) -> Video:
# --> 218     response, api_extras = await self._scrape_data(
#     219         link, self._video_response_type, scroll_down_time
#     220     )
#     221     return self._extract_video_from_response(response, api_extras)
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/tiktokapipy/async_api.py:176, in AsyncTikTokAPI._scrape_data(self, link, data_model, scroll_down_time)
# ...

# %%
def video_link(video_id: int) -> str:
    """Get a working link to a TikTok video from the video's unique id."""
    return f"https://m.tiktok.com/v/{video_id}"

# %%
video_link(7221139736071523590)
# Out:
# 'https://m.tiktok.com/v/7221139736071523590'
